# %% [markdown]
# Monitoring COVID-19 Infections through Wastewater Surveillance
# CMPSC 190DD/197A Project, Fall 2020
# Nick Bachelder, Anton de la Fuente, Zoe Holzer

# %% [markdown]
# PART A:
# 1. Using the model dynamics described in the previous section, and all the given and chosen parameters, simulate the behavior of the disease for 120 days for this single leaf node.

# %%
import numpy as np
part1 = np.load("part1a.npz")
part1.files
Ic_0 = part1["Ic_0"]
N = part1["N"]
gamma = part1["gamma"]
Lc = part1["Lc"]
Svc_0 = part1["Svc_0_pmf"]

# %%
import pandas as pd
S_0 = N-(Ic_0.sum())
I_0 = Ic_0.sum()
R_0 = 0
data = pd.DataFrame(Svc_0)

# %%
import random 
from random import Random
random.seed(a=None, version=2)
B0c = []
B1c = []
B2c = []
B3c = []
for i in range(4):
    B0c.append(random.uniform(0, 0.25))
    B1c.append(random.uniform(0.25, 0.5))
    B2c.append(random.uniform(0.5, 0.75))
    B3c.append(random.uniform(0.75, 1.0))
    Bvc = np.array([B0c, B1c, B2c, B3c])
for i in range(4):
    Bvc[i].sort()
Bvc = pd.DataFrame(Bvc)

# %%
def S_rate(Svc, Ic, N, Bvc, gamma):
    """Calculate the rate of change of suceptible group split by vulnerability and comorbidity, return a
    tuple where the first element is split on both categories, and the second element only split by comorbidity"""
    #This makes sure that once population hits 0 it doesn't affect the differential
    Svc[Svc < 0] = 0
    dSvcdt = ((Bvc * Svc * Ic)*-1)/N
    return dSvcdt

# %%
def I_rate(dSvcdt, Ic, gamma):
    """This function takes in the rate of change of S, sums along the vulnerability axis, and subtracts 
    Ic*gamma"""
    Ic[Ic < 0]= 0
    dIcdt = -dSvcdt.sum() - gamma*Ic
    return dIcdt

# %%
def R_rate(Ic, gamma):
    Ic[Ic < 0]= 0
    dRdt = gamma * Ic.sum()
    return dRdt

# %%
def SIR_rates(Svc, Ic, N, Bvc, gamma):
    dSvcdt = S_rate(Svc, Ic, N, Bvc, gamma)
    dIcdt = I_rate(dSvcdt, Ic, gamma)
    dRdt = R_rate(Ic, gamma)
    return dSvcdt, dIcdt, dRdt

# %%
def L_rate(Ic, Lc, N):
    Lrate= (Ic*Lc).sum()
    return Lrate

# %%
def simulation(t, Svc, Ic, N, Bvc, gamma, Lc, I_0):
    I = I_0
    R = 0
    S = Svc.sum().sum()
    SvcOverTime=[]
    IcOvertime=[]
    LOverTime=[]
    simulation = [[S, I, R]]
    for i in range(t):
        rates = SIR_rates(Svc, Ic, N, Bvc, gamma)
        Lrate= L_rate(Ic, Lc, N)
        Svc = Svc + rates[0]
        S = Svc.sum().sum()
        Ic = Ic + rates[1]
        I = Ic.sum()
        R = R + rates[2]
        L=Lrate.sum()
        simulation.append([S, I, R])
        SvcOverTime.insert(i,Svc)
        IcOvertime.insert(i,Ic)
        LOverTime.insert(i,L)
    results = pd.DataFrame(simulation, columns = ["S", "I", "R"])
    return results, SvcOverTime, IcOvertime, LOverTime

# %%
#The Svc data multiplied by the population to get raw population values split in both dimensions
t=120
Svc = pd.DataFrame(Svc_0) * (N - I_0)
Ic = Ic_0
sim = simulation(t, Svc, Ic, N, Bvc, gamma, Lc,I_0)

# %% [markdown]
# 2. Plot Sv,c and Ic values over time. (You can plot all Sv,c on the same plot. Same for Ic.). Also plot the overall S, I, R and L values.

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(sharex=True)
for a in range(0,120,8):
    for b in range(0,4):
        ax.scatter(a,sim[1][a][b][0],c='black',s=10)
        ax.scatter(a,sim[1][a][b][1],c='red',s=10)
        ax.scatter(a,sim[1][a][b][2],c='blue',s=10)
        ax.scatter(a,sim[1][a][b][3],c='green',s=10)
plt.title('Suseptable people over time by Vulnerability and Comorbidity Groups')
plt.ylabel('Number of People')
plt.xlabel('Day')
plt.show()

# %%
fig,ax=plt.subplots(sharex=True)
for a in range(0,120,8):
    ax.scatter(a,sim[2][a][0],c='black',s=10)
    ax.scatter(a,sim[2][a][1],c='red',s=10)
    ax.scatter(a,sim[2][a][2],c='blue',s=10)
    ax.scatter(a,sim[2][a][3],c='yellow',s=10) 
plt.title('Infected People Over Time by Comorbidity Group')
plt.ylabel('Number of People')
plt.xlabel('Day')
plt.show()

# %%
fig,ax=plt.subplots(sharex=True)
SIR=np.array(sim[0])
for a in range(0,120,8):
    ax.scatter(a,SIR[a][0],c='black',s=10)
    ax.scatter(a,SIR[a][1],c='red',s=10)
    ax.scatter(a,SIR[a][2],c='blue',s=10)
    ax.scatter(a,sim[3][a],c='yellow',s=10)
plt.title('Suseptable, Infected, Recovered, and Viral Load Over Time')
plt.ylabel('Number of People')
plt.xlabel('Day')
plt.show()

# %% [markdown]
# **3. Do the shapes of S, I, R look similar to what you expected? Which of these plots is the “curve” people refer to when they say “flatten the curve”?**
#
# The shapes of the model look about right except that we were not expecting the huge difference in scale between S and I or R after 120 days. The overall shape however is what we expected based off of what we learned in class and off of over COVID models currently available. Moreover, it is clear that the comorbidity groups largely impact the infected population over time, which makes perfect sense. When people say 'flatten the curve,' they are refering to the infected population curve (in blue on the last plot).

# %% [markdown]
# **4. Do you observe that some Sv,c compartments converged to zero while others converged to a positive value? Why do you think that is?**
#
# Yes, we did observe some compartments converging to positive values other then zero. We believe that is because specific βv,c values have a large affect on the overall model, especially because it is the reciprocal of the typical time until an infected person recovers, making it play a large part on the time series.

# %%
## Print the percentages of population that never got infected for all compartments (i.e. all values
## of v and c)

OriginalSvcPopulations = pd.DataFrame(Svc_0) * (N - I_0)
SvcFinalDay = sim[1][119]
PercentNotInfectedvc = SvcFinalDay / OriginalSvcPopulations
PercentNotInfectedvc
# Out:
#           0         1         2         3
# 0  0.995425  0.885317  0.653172  0.963415
# 1  0.981180  0.715957  0.313226  0.916164
# 2  0.970388  0.547652  0.114476  0.870937
# 3  0.957746  0.474345  0.048078  0.828264

# %%
## Redo but multiply all Beta values by 1/4. How does this change plots?

BvcRedo = Bvc * (1/4)

Svc = pd.DataFrame(Svc_0) * (N - I_0)
Ic = Ic_0
I = I_0
S = Svc.sum().sum()
R = 0
simRedo = simulation(t, Svc, Ic, N, BvcRedo, gamma, Lc,I_0)

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(sharex=True)
for a in range(0,120,8):
    for b in range(0,4):
        ax.scatter(a,simRedo[1][a][b][0],c='black',s=10)
        ax.scatter(a,simRedo[1][a][b][1],c='red',s=10)
        ax.scatter(a,simRedo[1][a][b][2],c='blue',s=10)
        ax.scatter(a,simRedo[1][a][b][3],c='green',s=10)
plt.title('Suseptible people over time by Vulnerability and Comorbidity Groups')
plt.ylabel('Number of People')
plt.xlabel('Day')

plt.show()

# %%
fig,ax=plt.subplots(sharex=True)
for a in range(0,120,8):
    ax.scatter(a,simRedo[2][a][0],c='black',s=10)
    ax.scatter(a,simRedo[2][a][1],c='red',s=10)
    ax.scatter(a,simRedo[2][a][2],c='blue',s=10)
    ax.scatter(a,simRedo[2][a][3],c='yellow',s=10) 
plt.ylim(0, 1000)

plt.title('Infected People Over Time by Comorbidity Group')
plt.ylabel('Number of People')
plt.xlabel('Day')

plt.show()

# %%
fig,ax=plt.subplots(sharex=True)
SIRRedo=simRedo[0]
for a in range(0,120,8):
    ax.scatter(a,SIR[a][0],c='black',s=10)
    ax.scatter(a,SIR[a][1],c='red',s=10)
    ax.scatter(a,SIR[a][2],c='blue',s=10)
    ax.scatter(a,simRedo[3][a],c='yellow',s=10)
    
plt.title('Suseptable, Infected, Recovered, and Viral Load Over Time')
plt.ylabel('Number of People')
plt.xlabel('Day')
plt.show()

# %% [markdown]
# What happened to the S, I, R plots? Did the “curve” flatten compared to the previous case?
#
# The plots changed drastically dy reducing the beta rate. Since the disease was being spread at a much slower rate, all v,c groups declined in cases over time, and the curve most definetly 'flattened.'

# %%
## Print the percentages of population that never got infected withthese βv,c values.

OriginalSvcPopulations = pd.DataFrame(Svc_0) * (N - I_0)
SvcFinalDay = simRedo[1][119]
PercentNotInfectedvcRedo = SvcFinalDay / OriginalSvcPopulations

# %%
PercentNotInfectedvc ## Many less people in each group were infected at a lower beta value
# Out:
#           0         1         2         3
# 0  0.995425  0.885317  0.653172  0.963415
# 1  0.981180  0.715957  0.313226  0.916164
# 2  0.970388  0.547652  0.114476  0.870937
# 3  0.957746  0.474345  0.048078  0.828264

# %%
import numpy as np
part2 = np.load("part1b.npz")
part2.files
Ic_0 = part2["Ic_0"]
N = part2["N"]
gamma = part2["gamma"]
Lc = part2["Lc"]
L_validation = part2["L_validation"]
L_test = part2["L_test"]
betas_validation = part2["betas_validation"]
pmfs = [[0.5, 0.3, 0.1, 0.1],[0.4, 0.3, 0.2, 0.1],[0.3,0.3,0.2,0.2],[0.1, 0.2, 0.3, 0.4]]
SVC0 = []
for item in pmfs:
    for i in range(5):
        SVC0.append(item)
Svc = (SVC0 * N) - Ic_0
Lc = np.tile(Lc, (5, 1))
I_0 = Ic_0.sum()

# %%
def S_rate(Svc, Ic, N, Bvc, gamma):
    """Calculate the rate of change of suceptible group split by vulnerability and comorbidity, return a
    tuple where the first element is split on both categories, and the second element only split by comorbidity"""
    #This makes sure that once population hits 0 it doesn't affect the differential
    dSvcdt = ((Bvc * Svc * Ic)*-1)/N
    return dSvcdt

# %%
def I_rate(dSvcdt, Ic, gamma):
    """This function takes in the rate of change of S, sums along the vulnerability axis, and subtracts 
    Ic*gamma"""
    dIcdt = -dSvcdt.sum() - gamma*Ic
    return dIcdt

# %%
def R_rate(Ic, gamma):
    dRdt = gamma * Ic.sum()
    return dRdt

# %%
def SIR_model(t, Y_array, Bvc, gamma, N):
    Svc = Y_array[0]
    Ic = Y_array[1]
    R = Y_array[2]
    dSvcdt = S_rate(Svc, Ic, N, Bvc, gamma)
    dIcdt = I_rate(dSvcdt, Ic, gamma)
    dRdt = R_rate(Ic, gamma)
    return [dSvcdt, dIcdt, dRdt]

# %%
I0c = []  
I1c = []  
I2c = []  
I3c = []  
S0c = []
S1c = []
S2c = []
S3c = []
for i in range(5):
    I0c.append(Ic_0[i])
    S0c.append(Svc[i])
for i in range(5,10):
    I1c.append(Ic_0[i])  
    S1c.append(Svc[i])
for i in range(10,15):
    I2c.append(Ic_0[i])  
    S2c.append(Svc[i])
for i in range(15,20):
    I3c.append(Ic_0[i])  
    S3c.append(Svc[i])

# %%
from itertools import combinations
import numpy as np
from sklearn.metrics import mean_squared_error
from scipy.integrate import solve_ivp

sol0c=[]
sol1c=[]
sol2c=[]
sol3c=[]

beta_grid= np.linspace(0,1,20)
t=np.linspace(0,19,20)
mmse=np.inf
optimal_beta = np.nan
simTrialsL = []
modelled_betas = np.array([])

#for beta_0, beta_1, beta_2, beta_3 in combinations(np.linspace(0,1,21),4):
beta = [0, .25, .5, .75]
for i in range(5):
    initial_conditions=np.array([S0c[i][0],I0c[i][0],0])
    soln_1 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[0], gamma, N),vectorized=True)
    initial_conditions=np.array([S0c[i][1],I0c[i][1],0])
    soln_2 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[1], gamma, N),vectorized=True)
    initial_conditions=np.array([S0c[i][2],I0c[i][2],0])
    soln_3 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[2], gamma, N),vectorized=True)
    initial_conditions=np.array([S0c[i][3],I0c[i][3],0])
    soln_4 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[3], gamma, N),vectorized=True)
    sol0c.append([soln_1.y,soln_2.y,soln_3.y,soln_4.y])
for i in range(5):
    initial_conditions=np.array([S1c[i][0],I1c[i][0],0])
    soln_1 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[0], gamma, N),vectorized=True)
    initial_conditions=np.array([S1c[i][1],I1c[i][1],0])
    soln_2 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[1], gamma, N),vectorized=True)
    initial_conditions=np.array([S1c[i][2],I1c[i][2],0])
    soln_3 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[2], gamma, N),vectorized=True)
    initial_conditions=np.array([S1c[i][3],I1c[i][3],0])
    soln_4 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[3], gamma, N),vectorized=True)
    sol1c.append([soln_1.y,soln_2.y,soln_3.y,soln_4.y])
for i in range(5):
    initial_conditions=np.array([S2c[i][0],I2c[i][0],0])
    soln_1 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[0], gamma, N),vectorized=True)
    initial_conditions=np.array([S2c[i][1],I2c[i][1],0])
    soln_2 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[1], gamma, N),vectorized=True)
    initial_conditions=np.array([S2c[i][2],I2c[i][2],0])
    soln_3 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[2], gamma, N),vectorized=True)
    initial_conditions=np.array([S2c[i][3],I2c[i][3],0])
    soln_4 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[3], gamma, N),vectorized=True)
    sol2c.append([soln_1.y,soln_2.y,soln_3.y,soln_4.y])
for i in range(5):
    initial_conditions=np.array([S3c[i][0],I3c[i][0],0])
    soln_1 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[0], gamma, N),vectorized=True)
    initial_conditions=np.array([S3c[i][1],I3c[i][1],0])
    soln_2 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[1], gamma, N),vectorized=True)
    initial_conditions=np.array([S3c[i][2],I3c[i][2],0])
    soln_3 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[2], gamma, N),vectorized=True)
    initial_conditions=np.array([S3c[i][3],I3c[i][3],0])
    soln_4 = solve_ivp(SIR_model, (t[0], t[-1]), initial_conditions, t_eval=t, args=(beta[3], gamma, N),vectorized=True)
    sol3c.append([soln_1.y,soln_2.y,soln_3.y,soln_4.y])

# for prediction in sol0c:
#     local_mmse = np.nan
#     mse = mean_squared_error(L_validation[i],prediction)
#     local_mmse = mse if mse < local_mmse else local_mmse
#     (mmse, optimal_beta) = (local_mmse, beta) if (local_mmse < mmse) else (mmse,optimal_beta)
#     np.append(modelled_betas, (mmse, optimal_beta))
# for prediction in sol0c:
#     local_mmse = np.nan
#     mse = mean_squared_error(L_validation[i],prediction)
#     local_mmse = mse if mse < local_mmse else local_mmse
#     (mmse, optimal_beta) = (local_mmse, beta) if (local_mmse < mmse) else (mmse,optimal_beta)
#     np.append(modelled_betas, (mmse, optimal_beta))
# for prediction in sol0c:
#     local_mmse = np.nan
#     mse = mean_squared_error(L_validation[i],prediction)
#     local_mmse = mse if mse < local_mmse else local_mmse
#     (mmse, optimal_beta) = (local_mmse, beta) if (local_mmse < mmse) else (mmse,optimal_beta)
#     np.append(modelled_betas, (mmse, optimal_beta))
# for prediction in sol0c:
#     local_mmse = np.nan
#     mse = mean_squared_error(L_validation[i],prediction)
#     local_mmse = mse if mse < local_mmse else local_mmse
#     (mmse, optimal_beta) = (local_mmse, beta) if (local_mmse < mmse) else (mmse,optimal_beta)
#     np.append(modelled_betas, (mmse, optimal_beta))
# Out:
# [[array([[4.97500000e+03, 4.97500000e+03, 4.97500000e+03, 4.97500000e+03,
#         4.97500000e+03, 4.97500000e+03, 4.97500000e+03, 4.97500000e+03,
#         4.97500000e+03, 4.97500000e+03, 4.97500000e+03, 4.97500000e+03,
#         4.97500000e+03, 4.97500000e+03, 4.97500000e+03, 4.97500000e+03,
#         4.97500000e+03, 4.97500000e+03, 4.97500000e+03, 4.97500000e+03],
#        [2.50000000e+01, 2.32765656e+01, 2.16717133e+01, 2.01773889e+01,
#         1.87861998e+01, 1.74911311e+01, 1.62855456e+01, 1.51631840e+01,
#         1.41181645e+01, 1.31449763e+01, 1.22384183e+01, 1.13941236e+01,
#         1.06080855e+01, 9.87646556e+00, 9.19559425e+00, 8.56197066e+00,
#         7.97226256e+00, 7.42330639e+00, 6.91210726e+00, 6.43583896e+00],
#        [0.00000000e+00, 1.72343436e+00, 3.32828670e+00, 4.82261111e+00,
#         6.21380021e+00, 7.50886891e+00, 8.71445437e+00, 9.83681599e+00,
#         1.08818355e+01, 1.18550237e+01, 1.27615817e+01, 1.36058764e+01,
#         1.43919145e+01, 1.51235344e+01, 1.58044058e+01, 1.64380293e+01,
#         1.70277374e+01, 1.75766936e+01, 1.80878927e+01, 1.85641610e+01]]), array([[9.96600000e+03, 9.96432409e+03, 9.96268427e+03, 9.96107978e+03,
#         9.95950986e+03, 9.95797378e+03, 9.95647081e+03, 9.95500024e+03,
#         9.95356137e+03, 9.95215353e+03, 9.95077607e+03, 9.94942832e+03,
#         9.94810967e+03, 9.94681948e+03, 9.94555714e+03, 9.94432206e+03,
#         9.94311365e+03, 9.94193134e+03, 9.94077456e+03, 9.93964277e+03],
#        [3.40000000e+01, 3.32733823e+01, 3.25620232e+01, 3.18656140e+01,
#         3.11838517e+01, 3.05164388e+01, 2.98630833e+01, 2.92234982e+01,
#         2.85974004e+01, 2.79845159e+01, 2.73845759e+01, 2.67973163e+01,
#         2.62224773e+01, 2.56598040e+01, 2.51090459e+01, 2.45699570e+01,
#         2.40422961e+01, 2.35258264e+01, 2.30203159e+01, 2.25255368e+01],
#        [0.00000000e+00, 2.40252913e+00, 4.75370441e+00, 7.05460380e+00,
#         9.30628393e+00, 1.15097806e+01, 1.36661089e+01, 1.57762650e+01,
#         1.78412302e+01, 1.98619519e+01, 2.18393586e+01, 2.37743618e+01,
#         2.56678563e+01, 2.75207200e+01, 2.93338139e+01, 3.11079822e+01,
#         3.28440523e+01, 3.45428346e+01, 3.62051228e+01, 3.78316937e+01]]), array([[1.49840000e+04, 1.49815063e+04, 1.49788096e+04, 1.49758935e+04,
#         1.49727405e+04, 1.49693319e+04, 1.49656467e+04, 1.49616626e+04,
#         1.49573554e+04, 1.49526993e+04, 1.49476666e+04, 1.49422273e+04,
#         1.49363488e+04, 1.49299969e+04, 1.49231342e+04, 1.49157198e+04,
#         1.49077100e+04, 1.48990578e+04, 1.48897131e+04, 1.48796224e+04],
#        [1.60000000e+01, 1.73048679e+01, 1.87157156e+01, 2.02411036e+01,
#         2.18900454e+01, 2.36724064e+01, 2.55989302e+01, 2.76812391e+01,
#         2.99318341e+01, 3.23640945e+01, 3.49922784e+01, 3.78318873e+01,
#         4.08996573e+01, 4.42132824e+01, 4.77920253e+01, 5.16567225e+01,
#         5.58297842e+01, 6.03351941e+01, 6.51985098e+01, 7.04468625e+01],
#        [0.00000000e+00, 1.18885318e+00, 2.47469543e+00, 3.86544059e+00,
#         5.36940592e+00, 6.99572269e+00, 8.75436404e+00, 1.06561450e+01,
#         1.27127226e+01, 1.49365956e+01, 1.73411048e+01, 1.99408299e+01,
#         2.27515103e+01, 2.57897690e+01, 2.90738239e+01, 3.26234938e+01,
#         3.64601981e+01, 4.06069568e+01, 4.50883906e+01, 4.99307206e+01]]), array([[1.99720000e+04, 1.99625800e+04, 1.99507535e+04, 1.99359133e+04,
#         1.99172923e+04, 1.98939399e+04, 1.98646945e+04, 1.98280834e+04,
#         1.97822521e+04, 1.97249642e+04, 1.96535705e+04, 1.95647408e+04,
#         1.94543450e+04, 1.93174810e+04, 1.91484742e+04, 1.89408780e+04,
#         1.86874115e+04, 1.83796773e+04, 1.80090937e+04, 1.75673314e+04],
#        [2.80000000e+01, 3.51734537e+01, 4.41779626e+01, 5.54747819e+01,
#         6.96459141e+01, 8.74111240e+01, 1.09650706e+02, 1.37478546e+02,
#         1.72291345e+02, 2.15768994e+02, 2.69883604e+02, 3.37128395e+02,
#         4.20590615e+02, 5.23862636e+02, 6.51040891e+02, 8.06725882e+02,
#         9.96025270e+02, 1.22469444e+03, 1.49830698e+03, 1.82180772e+03],
#        [0.00000000e+00, 2.24653091e+00, 5.06849017e+00, 8.61187917e+00,
#         1.30617831e+01, 1.86489647e+01, 2.56547785e+01, 3.44380903e+01,
#         4.54565544e+01, 5.92667831e+01, 7.65459317e+01, 9.81308549e+01,
#         1.25064346e+02, 1.58656356e+02, 2.00484916e+02, 2.52396142e+02,
#         3.16563265e+02, 3.95628283e+02, 4.92599360e+02, 6.10860900e+02]])], [array([[4.97700000e+03, 4.97700000e+03, 4.97700000e+03, 4.97700000e+03,
#         4.97700000e+03, 4.97700000e+03, 4.97700000e+03, 4.97700000e+03,
#         4.97700000e+03, 4.97700000e+03, 4.97700000e+03, 4.97700000e+03,
#         4.97700000e+03, 4.97700000e+03, 4.97700000e+03, 4.97700000e+03,
#         4.97700000e+03, 4.97700000e+03, 4.97700000e+03, 4.97700000e+03],
#        [2.30000000e+01, 2.14144433e+01, 1.99379424e+01, 1.85630500e+01,
#         1.72830355e+01, 1.60914962e+01, 1.49823574e+01, 1.39498721e+01,
#         1.29886213e+01, 1.20935136e+01, 1.12597883e+01, 1.04832311e+01,
#         9.76014886e+00, 9.08702649e+00, 8.46050910e+00, 7.87740176e+00,
#         7.33466957e+00, 6.82943763e+00, 6.35899104e+00, 5.92077493e+00],
#        [0.00000000e+00, 1.58555667e+00, 3.06205760e+00, 4.43695003e+00,
#         5.71696453e+00, 6.90850377e+00, 8.01764258e+00, 9.05012788e+00,
#         1.00113787e+01, 1.09064864e+01, 1.17402117e+01, 1.25167689e+01,
#         1.32398511e+01, 1.39129735e+01, 1.45394909e+01, 1.51225982e+01,
#         1.56653304e+01, 1.61705624e+01, 1.66410090e+01, 1.70792251e+01]]), array([[9.91600000e+03, 9.91188132e+03, 9.90785338e+03, 9.90391424e+03,
#         9.90006192e+03, 9.89629457e+03, 9.89261038e+03, 9.88900757e+03,
#         9.88548438e+03, 9.88203911e+03, 9.87867006e+03, 9.87537558e+03,
#         9.87215405e+03, 9.86900387e+03, 9.86592348e+03, 9.86291136e+03,
#         9.85996600e+03, 9.85708594e+03, 9.85426974e+03, 9.85151600e+03],
#        [8.40000000e+01, 8.21837745e+01, 8.04051815e+01, 7.86635117e+01,
#         7.69580540e+01, 7.52881243e+01, 7.36530522e+01, 7.20521764e+01,
#         7.04848442e+01, 6.89504117e+01, 6.74482439e+01, 6.59777146e+01,
#         6.45382065e+01, 6.31291108e+01, 6.17498278e+01, 6.03997666e+01,
#         5.90783450e+01, 5.77849897e+01, 5.65191362e+01, 5.52802287e+01],
#        [0.00000000e+00, 5.93490870e+00, 1.17414352e+01, 1.74222496e+01,
#         2.29800235e+01, 2.84173010e+01, 3.37365637e+01, 3.89402532e+01,
#         4.40307709e+01, 4.90104781e+01, 5.38816958e+01, 5.86467053e+01,
#         6.33077473e+01, 6.78670228e+01, 7.23266924e+01, 7.66888767e+01,
#         8.09556562e+01, 8.51290711e+01, 8.92111218e+01, 9.32037683e+01]]), array([[1.49290000e+04, 1.49179811e+04, 1.49060805e+04, 1.48932298e+04,
#         1.48793557e+04, 1.48643801e+04, 1.48482200e+04, 1.48307861e+04,
#         1.48119823e+04, 1.47917058e+04, 1.47698477e+04, 1.47462920e+04,
#         1.47209166e+04, 1.46935925e+04, 1.46641841e+04, 1.46325454e+04,
#         1.45985226e+04, 1.45619550e+04, 1.45226740e+04, 1.44805031e+04],
#        [7.10000000e+01, 7.67449033e+01, 8.29451443e+01, 8.96352125e+01,
#         9.68518546e+01, 1.04634173e+02, 1.13024093e+02, 1.22066359e+02,
#         1.31808526e+02, 1.42300966e+02, 1.53596865e+02, 1.65752225e+02,
#         1.78825861e+02, 1.92879404e+02, 2.07977341e+02, 2.24188229e+02,
#         2.41583516e+02, 2.60236757e+02, 2.80223873e+02, 3.01623147e+02],
#        [0.00000000e+00, 5.27399679e+00, 1.09744012e+01, 1.71349594e+01,
#         2.37924695e+01, 3.09857746e+01, 3.87558789e+01, 4.71475274e+01,
#         5.62092158e+01, 6.59931899e+01, 7.65554456e+01, 8.79557294e+01,
#         1.00257538e+02, 1.13528118e+02, 1.27838560e+02, 1.43266352e+02,
#         1.59893863e+02, 1.77808248e+02, 1.97102159e+02, 2.17873743e+02]]), array([[1.99690000e+04, 1.99585727e+04, 1.99454836e+04, 1.99290608e+04,
#         1.99084584e+04, 1.98826284e+04, 1.98502920e+04, 1.98098192e+04,
#         1.97591772e+04, 1.96959310e+04, 1.96171893e+04, 1.95192827e+04,
#         1.93977249e+04, 1.92472528e+04, 1.90618267e+04, 1.88346304e+04,
#         1.85579999e+04, 1.82232099e+04, 1.78217069e+04, 1.73454573e+04],
#        [3.10000000e+01, 3.89400752e+01, 4.89052186e+01, 6.14056168e+01,
#         7.70826316e+01, 9.67294346e+01, 1.21314815e+02, 1.52070016e+02,
#         1.90523990e+02, 2.38503389e+02, 2.98151773e+02, 3.72222820e+02,
#         4.64050941e+02, 5.77469447e+02, 7.16810544e+02, 8.86904415e+02,
#         1.09305643e+03, 1.34116765e+03, 1.63661199e+03, 1.98388423e+03],
#        [0.00000000e+00, 2.48719203e+00, 5.61115483e+00, 9.53362757e+00,
#         1.44589518e+01, 2.06422063e+01, 2.83932067e+01, 3.81108274e+01,
#         5.02987777e+01, 6.55656139e+01, 8.46588977e+01, 1.08494497e+02,
#         1.38224190e+02, 1.75277715e+02, 2.21362766e+02, 2.78465226e+02,
#         3.48943692e+02, 4.35622421e+02, 5.41681124e+02, 6.70658496e+02]])], [array([[4909.        , 4909.        , 4909.        , 4909.        ,
#         4909.        , 4909.        , 4909.        , 4909.        ,
#         4909.        , 4909.        , 4909.        , 4909.        ,
#         4909.        , 4909.        , 4909.        , 4909.        ,
#         4909.        , 4909.        , 4909.        , 4909.        ],
#        [  91.        ,   84.7267101 ,   78.88588854,   73.44712134,
#           68.38113961,   63.66384202,   59.27250931,   55.18541045,
#           51.38180266,   47.84193139,   44.54703031,   41.47932135,
#           38.62201465,   35.95974594,   33.48055858,   31.17234469,
#           29.0234262 ,   27.02279829,   25.16012946,   23.42576145],
#        [   0.        ,    6.2732899 ,   12.11411146,   17.55287866,
#           22.61886039,   27.33615798,   31.72749069,   35.81458955,
#           39.61819734,   43.15806861,   46.45296969,   49.52067865,
#           52.37798535,   55.04025406,   57.51944142,   59.82765531,
#           61.9765738 ,   63.97720171,   65.83987054,   67.57423855]]), array([[9.93000000e+03, 9.92656268e+03, 9.92320061e+03, 9.91991220e+03,
#         9.91669582e+03, 9.91354991e+03, 9.91047298e+03, 9.90746355e+03,
#         9.90452018e+03, 9.90164146e+03, 9.89882598e+03, 9.89607239e+03,
#         9.89337934e+03, 9.89074551e+03, 9.88816963e+03, 9.88565041e+03,
#         9.88318664e+03, 9.88077709e+03, 9.87842058e+03, 9.87611595e+03],
#        [7.00000000e+01, 6.84913901e+01, 6.70141540e+01, 6.55676892e+01,
#         6.41513961e+01, 6.27646847e+01, 6.14069865e+01, 6.00777413e+01,
#         5.87763970e+01, 5.75024093e+01, 5.62552417e+01, 5.50343660e+01,
#         5.38392619e+01, 5.26694167e+01, 5.15243262e+01, 5.04034937e+01,
#         4.93064308e+01, 4.82326568e+01, 4.71816991e+01, 4.61530932e+01],
#        [0.00000000e+00, 4.94593256e+00, 9.78523134e+00, 1.45201157e+01,
#         1.91527881e+01, 2.36854067e+01, 2.81200369e+01, 3.24587092e+01,
#         3.67034203e+01, 4.08561330e+01, 4.49187762e+01, 4.88932452e+01,
#         5.27814010e+01, 5.65850710e+01, 6.03060487e+01, 6.39460937e+01,
#         6.75069318e+01, 7.09902548e+01, 7.43977208e+01, 7.77309538e+01]]), array([[1.49100000e+04, 1.48960530e+04, 1.48809962e+04, 1.48647452e+04,
#         1.48472093e+04, 1.48282927e+04, 1.48078926e+04, 1.47858991e+04,
#         1.47621948e+04, 1.47366557e+04, 1.47091501e+04, 1.46795395e+04,
#         1.46476781e+04, 1.46134128e+04, 1.45765800e+04, 1.45370086e+04,
#         1.44945204e+04, 1.44489300e+04, 1.44000448e+04, 1.43476651e+04],
#        [9.00000000e+01, 9.72623803e+01, 1.05095546e+02, 1.13541713e+02,
#         1.22645575e+02, 1.32455193e+02, 1.43021591e+02, 1.54398697e+02,
#         1.66643340e+02, 1.79815250e+02, 1.93977058e+02, 2.09194297e+02,
#         2.25535402e+02, 2.43071723e+02, 2.61878074e+02, 2.82032180e+02,
#         3.03613214e+02, 3.26701698e+02, 3.51379507e+02, 3.77729865e+02],
#        [0.00000000e+00, 6.68466809e+00, 1.39082143e+01, 2.17131219e+01,
#         3.01451590e+01, 3.92521004e+01, 4.90857679e+01, 5.97022329e+01,
#         7.11618169e+01, 8.35290911e+01, 9.68728765e+01, 1.11266244e+02,
#         1.26786514e+02, 1.43515491e+02, 1.61541886e+02, 1.80959205e+02,
#         2.01866403e+02, 2.24368311e+02, 2.48575646e+02, 2.74605003e+02]]), array([[1.99100000e+04, 1.98798474e+04, 1.98420860e+04, 1.97948395e+04,
#         1.97358142e+04, 1.96621799e+04, 1.95704602e+04, 1.94565292e+04,
#         1.93156752e+04, 1.91418110e+04, 1.89279821e+04, 1.86666968e+04,
#         1.83499253e+04, 1.79693331e+04, 1.75173640e+04, 1.69841748e+04,
#         1.63634521e+04, 1.56536008e+04, 1.48577443e+04, 1.39837243e+04],
#        [9.00000000e+01, 1.12935461e+02, 1.41643127e+02, 1.77536420e+02,
#         2.22339860e+02, 2.78176717e+02, 3.47633628e+02, 4.33760770e+02,
#         5.39974020e+02, 6.70766846e+02, 8.31149944e+02, 1.02630824e+03,
#         1.26160089e+03, 1.54236073e+03, 1.87285702e+03, 2.25879141e+03,
#         2.70241492e+03, 3.20152184e+03, 3.74944967e+03, 4.33507920e+03],
#        [0.00000000e+00, 7.21712138e+00, 1.62708395e+01, 2.76240423e+01,
#         4.18459563e+01, 5.96433904e+01, 8.19061741e+01, 1.09710063e+02,
#         1.44350795e+02, 1.87422191e+02, 2.40867921e+02, 3.06994996e+02,
#         3.88473773e+02, 4.88306117e+02, 6.09778950e+02, 7.57033780e+02,
#         9.34132988e+02, 1.14487734e+03, 1.39280599e+03, 1.68119648e+03]])], [array([[4.96800000e+03, 4.96800000e+03, 4.96800000e+03, 4.96800000e+03,
#         4.96800000e+03, 4.96800000e+03, 4.96800000e+03, 4.96800000e+03,
#         4.96800000e+03, 4.96800000e+03, 4.96800000e+03, 4.96800000e+03,
#         4.96800000e+03, 4.96800000e+03, 4.96800000e+03, 4.96800000e+03,
#         4.96800000e+03, 4.96800000e+03, 4.96800000e+03, 4.96800000e+03],
#        [3.20000000e+01, 2.97939955e+01, 2.77399482e+01, 2.58275235e+01,
#         2.40470494e+01, 2.23894172e+01, 2.08460817e+01, 1.94090487e+01,
#         1.80701892e+01, 1.68228851e+01, 1.56614754e+01, 1.45804993e+01,
#         1.35746970e+01, 1.26390089e+01, 1.17685764e+01, 1.09587411e+01,
#         1.02050455e+01, 9.50323238e+00, 8.84924535e+00, 8.23939326e+00],
#        [0.00000000e+00, 2.20600451e+00, 4.26005185e+00, 6.17247654e+00,
#         7.95295062e+00, 9.61058277e+00, 1.11539183e+01, 1.25909513e+01,
#         1.39298108e+01, 1.51771149e+01, 1.63385246e+01, 1.74195007e+01,
#         1.84253030e+01, 1.93609911e+01, 2.02314236e+01, 2.10412589e+01,
#         2.17949545e+01, 2.24967676e+01, 2.31507546e+01, 2.37606067e+01]]), array([[9.98900000e+03, 9.98845648e+03, 9.98792454e+03, 9.98740393e+03,
#         9.98689442e+03, 9.98639575e+03, 9.98590772e+03, 9.98543009e+03,
#         9.98496265e+03, 9.98450518e+03, 9.98405747e+03, 9.98361931e+03,
#         9.98319049e+03, 9.98277082e+03, 9.98236011e+03, 9.98195815e+03,
#         9.98156477e+03, 9.98117977e+03, 9.98080298e+03, 9.98043423e+03],
#        [1.10000000e+01, 1.07661864e+01, 1.05373144e+01, 1.03132786e+01,
#         1.00939771e+01, 9.87931237e+00, 9.66918880e+00, 9.46351223e+00,
#         9.26219017e+00, 9.06513177e+00, 8.87224778e+00, 8.68345062e+00,
#         8.49865430e+00, 8.31777448e+00, 8.14072846e+00, 7.96743514e+00,
#         7.79781509e+00, 7.63179047e+00, 7.46928508e+00, 7.31022438e+00],
#        [0.00000000e+00, 7.77334077e-01, 1.53814429e+00, 2.28278724e+00,
#         3.01160756e+00, 3.72493424e+00, 4.42309064e+00, 5.10639451e+00,
#         5.77515801e+00, 6.42968764e+00, 7.07028435e+00, 7.69724342e+00,
#         8.31085455e+00, 8.91140181e+00, 9.49916368e+00, 1.00744130e+01,
#         1.06374170e+01, 1.11884374e+01, 1.17277301e+01, 1.22555455e+01]]), array([[1.49320000e+04, 1.49214442e+04, 1.49100430e+04, 1.48977308e+04,
#         1.48844368e+04, 1.48700860e+04, 1.48545986e+04, 1.48378886e+04,
#         1.48198635e+04, 1.48004243e+04, 1.47794657e+04, 1.47568757e+04,
#         1.47325360e+04, 1.47063218e+04, 1.46781019e+04, 1.46477356e+04,
#         1.46150732e+04, 1.45799584e+04, 1.45422271e+04, 1.45017075e+04],
#        [6.80000000e+01, 7.35045348e+01, 7.94459334e+01, 8.58573966e+01,
#         9.27743620e+01, 1.00234497e+02, 1.08278171e+02, 1.16948548e+02,
#         1.26291580e+02, 1.36356010e+02, 1.47193370e+02, 1.58857983e+02,
#         1.71406963e+02, 1.84900212e+02, 1.99400424e+02, 2.14974060e+02,
#         2.31691120e+02, 2.49623619e+02, 2.68846059e+02, 2.89435430e+02],
#        [0.00000000e+00, 5.05123331e+00, 1.05110528e+01, 1.64118377e+01,
#         2.27888148e+01, 2.96795304e+01, 3.71232571e+01, 4.51628792e+01,
#         5.38449484e+01, 6.32196838e+01, 7.33409712e+01, 8.42663640e+01,
#         9.60570827e+01, 1.08778015e+02, 1.22497716e+02, 1.37290312e+02,
#         1.53235702e+02, 1.70418019e+02, 1.88926814e+02, 2.08857048e+02]]), array([[1.99190000e+04, 1.98918460e+04, 1.98578285e+04, 1.98152472e+04,
#         1.97620144e+04, 1.96955694e+04, 1.96127334e+04, 1.95096888e+04,
#         1.93820439e+04, 1.92243935e+04, 1.90300804e+04, 1.87918787e+04,
#         1.85020201e+04, 1.81521932e+04, 1.77344337e+04, 1.72397954e+04,
#         1.66603780e+04, 1.59926203e+04, 1.52373170e+04, 1.43996191e+04],
#        [8.10000000e+01, 1.01658001e+02, 1.27525144e+02, 1.59884180e+02,
#         2.00304888e+02, 2.50713553e+02, 3.13482916e+02, 3.91443036e+02,
#         4.87805968e+02, 6.06528171e+02, 7.52489316e+02, 9.30777141e+02,
#         1.14666035e+03, 1.40558860e+03, 1.71238663e+03, 2.07222765e+03,
#         2.48893523e+03, 2.96217678e+03, 3.48744840e+03, 4.05607489e+03],
#        [0.00000000e+00, 6.49597672e+00, 1.46463556e+01, 2.48686557e+01,
#         3.76807470e+01, 5.37170007e+01, 7.37837028e+01, 9.88681184e+01,
#         1.30150131e+02, 1.69078325e+02, 2.17430312e+02, 2.77344131e+02,
#         3.51319571e+02, 4.42218167e+02, 5.53179672e+02, 6.87976993e+02,
#         8.50686740e+02, 1.04520293e+03, 1.27523463e+03, 1.54430598e+03]])], [array([[4.96600000e+03, 4.96600000e+03, 4.96600000e+03, 4.96600000e+03,
#         4.96600000e+03, 4.96600000e+03, 4.96600000e+03, 4.96600000e+03,
#         4.96600000e+03, 4.96600000e+03, 4.96600000e+03, 4.96600000e+03,
#         4.96600000e+03, 4.96600000e+03, 4.96600000e+03, 4.96600000e+03,
#         4.96600000e+03, 4.96600000e+03, 4.96600000e+03, 4.96600000e+03],
#        [3.40000000e+01, 3.16561200e+01, 2.94737238e+01, 2.74418109e+01,
#         2.55500737e+01, 2.37888204e+01, 2.21489755e+01, 2.06218647e+01,
#         1.91989254e+01, 1.78736019e+01, 1.66397770e+01, 1.54915555e+01,
#         1.44232646e+01, 1.34294537e+01, 1.25048943e+01, 1.16445802e+01,
#         1.08437272e+01, 1.00977735e+01, 9.40237949e+00, 8.75420819e+00],
#        [0.00000000e+00, 2.34388004e+00, 4.52627624e+00, 6.55818908e+00,
#         8.44992629e+00, 1.02111796e+01, 1.18510245e+01, 1.33781353e+01,
#         1.48010746e+01, 1.61263981e+01, 1.73602230e+01, 1.85084445e+01,
#         1.95767354e+01, 2.05705463e+01, 2.14951057e+01, 2.23554198e+01,
#         2.31562728e+01, 2.39022265e+01, 2.45976205e+01, 2.52457918e+01]]), array([[9.96300000e+03, 9.96117679e+03, 9.95939290e+03, 9.95764750e+03,
#         9.95593976e+03, 9.95426887e+03, 9.95263406e+03, 9.95103453e+03,
#         9.94946954e+03, 9.94793835e+03, 9.94644025e+03, 9.94497452e+03,
#         9.94354048e+03, 9.94213744e+03, 9.94076474e+03, 9.93942173e+03,
#         9.93810776e+03, 9.93682222e+03, 9.93556449e+03, 9.93433396e+03],
#        [3.70000000e+01, 3.62087125e+01, 3.54340279e+01, 3.46756118e+01,
#         3.39331358e+01, 3.32062773e+01, 3.24947197e+01, 3.17981498e+01,
#         3.11162628e+01, 3.04487619e+01, 2.97953553e+01, 2.91557560e+01,
#         2.85296822e+01, 2.79168566e+01, 2.73170072e+01, 2.67298669e+01,
#         2.61551732e+01, 2.55926690e+01, 2.50421018e+01, 2.45032240e+01],
#        [0.00000000e+00, 2.61449714e+00, 5.17306915e+00, 7.67688922e+00,
#         1.01271074e+01, 1.25248512e+01, 1.48712251e+01, 1.71673206e+01,
#         1.94141975e+01, 2.16128857e+01, 2.37643964e+01, 2.58697227e+01,
#         2.79298394e+01, 2.99457028e+01, 3.19182511e+01, 3.38484040e+01,
#         3.57370630e+01, 3.75851111e+01, 3.93934132e+01, 4.11628157e+01]]), array([[1.49520000e+04, 1.49445373e+04, 1.49364733e+04, 1.49277606e+04,
#         1.49183482e+04, 1.49081813e+04, 1.48972005e+04, 1.48853440e+04,
#         1.48725449e+04, 1.48587307e+04, 1.48438231e+04, 1.48277382e+04,
#         1.48103866e+04, 1.47916731e+04, 1.47714969e+04, 1.47497516e+04,
#         1.47263249e+04, 1.47010971e+04, 1.46739372e+04, 1.46447093e+04],
#        [4.80000000e+01, 5.18967304e+01, 5.61054579e+01, 6.06503897e+01,
#         6.55575578e+01, 7.08548585e+01, 7.65720931e+01, 8.27408738e+01,
#         8.93952788e+01, 9.65719397e+01, 1.04310042e+02, 1.12651325e+02,
#         1.21640083e+02, 1.31323160e+02, 1.41749959e+02, 1.52972433e+02,
#         1.65045090e+02, 1.78025906e+02, 1.91977345e+02, 2.06963775e+02],
#        [0.00000000e+00, 3.56596260e+00, 7.42127343e+00, 1.15890332e+01,
#         1.60942132e+01, 2.09638216e+01, 2.62273998e+01, 3.19151041e+01,
#         3.80597772e+01, 4.46973551e+01, 5.18668671e+01, 5.96104360e+01,
#         6.79732778e+01, 7.70037021e+01, 8.67531118e+01, 9.72760032e+01,
#         1.08629966e+02, 1.20876974e+02, 1.34085407e+02, 1.48326940e+02]]), array([[1.99590000e+04, 1.99452182e+04, 1.99279259e+04, 1.99062381e+04,
#         1.98790491e+04, 1.98449979e+04, 1.98024066e+04, 1.97491469e+04,
#         1.96826241e+04, 1.95997820e+04, 1.94969075e+04, 1.93692887e+04,
#         1.92114205e+04, 1.90170307e+04, 1.87790797e+04, 1.84898371e+04,
#         1.81406617e+04, 1.77224905e+04, 1.72275936e+04, 1.66496820e+04],
#        [4.10000000e+01, 5.14925654e+01, 6.46545028e+01, 8.11570869e+01,
#         1.01837313e+02, 1.27723449e+02, 1.60084565e+02, 2.00521513e+02,
#         2.50977803e+02, 3.13727552e+02, 3.91516202e+02, 4.87867537e+02,
#         6.06800455e+02, 7.52794262e+02, 9.30788667e+02, 1.14609506e+03,
#         1.40445490e+03, 1.71161408e+03, 2.07170745e+03, 2.48715427e+03],
#        [0.00000000e+00, 3.28928383e+00, 7.41958309e+00, 1.26048043e+01,
#         1.91136355e+01, 2.72786346e+01, 3.75088200e+01, 5.03315679e+01,
#         6.63981183e+01, 8.64904814e+01, 1.11576298e+02, 1.42843777e+02,
#         1.81779013e+02, 2.30175000e+02, 2.90131630e+02, 3.64067853e+02,
#         4.54883395e+02, 5.65895399e+02, 7.00698947e+02, 8.63163695e+02]])]]
